# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("E-commerce data.csv", encoding='latin-1')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# #Converting order and ship column datatype into date_time

# %%
import pandas as pd
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# data.head(3)

# %%
data['Order Month'] = data['Order Date'].dt.month
data['Order Year'] = data['Order Date'].dt.year
data['Order Day of Week'] = data['Order Date'].dt.dayofweek

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %% [markdown]
# # Monthly sales analysis

# %%
sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
import matplotlib.pyplot as plt

# Assuming sales_by_month is a DataFrame with columns 'Order Month' and 'Sales'
plt.figure(figsize=(6, 4))  # Optional: size of the figure
plt.plot(sales_by_month['Order Month'], sales_by_month['Sales'], marker='o')

plt.title('Month Sales Analysis')
plt.xlabel('Order Month')
plt.ylabel('Sales')
plt.grid(True)
plt.xticks(rotation=45)  # Optional: rotate x-axis labels if they are long
plt.tight_layout()       # Optional: adjusts layout to prevent cutoff
plt.show()

# %%
#Sales by category

# %%
data.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Month  Order Year  Order day of week
# 0  41.9136           11        2016                  1
#
# [1 rows x 24 columns]

# %%
sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()

import matplotlib.pyplot as plt

# Grouping already done
# sales_by_category = data.groupby('Category')['Sales'].sum().reset_index()

# Pie chart
plt.figure(figsize=(2, 2))
plt.pie(
    sales_by_category['Sales'],                # Values
    labels=sales_by_category['Category'],      # Labels
    autopct='%1.1f%%',                         # Show percentages
    startangle=140                             # Rotate chart for better visual
)
plt.title('Sales Distribution by Category')
plt.axis('equal')  # Makes the pie chart a circle
plt.show()

# %% [markdown]
# # sales by sub-category

# %%
data.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ...  \
# 0      Claire Gute   Consumer  United States    Henderson  ...
# 1      Claire Gute   Consumer  United States    Henderson  ...
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
# ...

# %%
sales_by_subcategory = data.groupby('Sub-Category')['Sales'].sum().reset_index()

import matplotlib.pyplot as plt

# Sort data for better visual (optional)
sales_by_subcategory = sales_by_subcategory.sort_values('Sales', ascending=False)

# Plotting
plt.figure(figsize=(12, 6))
plt.bar(sales_by_subcategory['Sub-Category'], sales_by_subcategory['Sales'], color='skyblue')

# Adding labels and title
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales')
plt.title('Sales by Sub-Category')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()       # Adjust layout to avoid clipping
plt.show()

# %% [markdown]
# # Monthly profit analysis

# %%
data.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Month  Order Year  Order day of week
# 0  41.9136           11        2016                  1
#
# [1 rows x 24 columns]

# %%
monthly_profit = data.groupby('Order Month')['Profit'].sum().reset_index()

# Optional: Sort by month
# monthly_profit['Order Month'] = pd.to_datetime(monthly_profit['Order Month'])
# monthly_profit = monthly_profit.sort_values('Order Month')

plt.figure(figsize=(12, 6))
bars = plt.bar(monthly_profit['Order Month'], monthly_profit['Profit'], color='green')

# Labels and title
plt.xlabel('Order Month')
plt.ylabel('Total Profit')
plt.title('Monthly Profit Analysis')
plt.xticks(rotation=45)

# Write values on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:.0f}', 
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Profit by subcategory

# %%
profit_by_subcategory = data.groupby('Sub-Category')['Profit'].sum().reset_index()

import matplotlib.pyplot as plt

# Optional: sort by profit for better visualization
profit_by_subcategory = profit_by_subcategory.sort_values('Profit', ascending=False)

# Create bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(profit_by_subcategory['Sub-Category'], profit_by_subcategory['Profit'], color='coral')

# Add chart labels
plt.xlabel('Sub-Category')
plt.ylabel('Total Profit')
plt.title('Profit by Sub-Category')
plt.xticks(rotation=45)

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height, f'{height:.0f}',
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Profit by Category

# %%
profit_by_category = data.groupby('Category')['Profit'].sum().reset_index()

import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(4, 4))
wedges, texts, autotexts = plt.pie(
    profit_by_category['Profit'],
    labels=profit_by_category['Category'],
    autopct='%1.1f%%',
    startangle=140,
    wedgeprops=dict(width=0.5)  # This creates the "donut" hole
)

# Add center title or styling if needed
plt.title('Profit Distribution by Category')
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular
plt.show()

# %%
data.head(1)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ...   Category  \
# 0   Claire Gute  Consumer  United States  Henderson  ...  Furniture
#
#    Sub-Category                       Product Name   Sales Quantity Discount  \
# 0     Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#     Profit  Order Month  Order Year  Order day of week
# 0  41.9136           11        2016                  1
#
# [1 rows x 24 columns]

# %% [markdown]
# # Sales and profit - customer segment

# %%
sales_profit_by_segment = data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()

import matplotlib.pyplot as plt
import numpy as np

# Data
segments = sales_profit_by_segment['Segment']
sales = sales_profit_by_segment['Sales']
profit = sales_profit_by_segment['Profit']

# X-axis positions
x = np.arange(len(segments))  # [0, 1, 2]
width = 0.35  # Width of bars

# Plot
plt.figure(figsize=(10, 6))
bars1 = plt.bar(x - width/2, sales, width, label='Sales', color='orange')
bars2 = plt.bar(x + width/2, profit, width, label='Profit', color='yellow')

# Add labels and title
plt.xlabel('Segment')
plt.ylabel('Amount')
plt.title('Sales and Profit by Segment')
plt.xticks(x, segments)
plt.legend()

# Add values on bars
for bar in bars1:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():.0f}',
             ha='center', va='bottom', fontsize=9)

for bar in bars2:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():.0f}',
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # sales to profit ratio

# %%
sales_profit_by_segment = data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()

sales_profit_by_segment['sales_profit_ratio'] = sales_profit_by_segment['Sales']/sales_profit_by_segment['Profit']

print(sales_profit_by_segment[['Segment','sales_profit_ratio']])
# Out:
#        Segment  sales_profit_ratio
# 0     Consumer            8.659471
# 1    Corporate            7.677245
# 2  Home Office            7.125416
